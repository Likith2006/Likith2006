# %% [markdown]
# <a href="https://colab.research.google.com/github/Likith2006/Likith2006/blob/main/ASSINEMENT_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Boston-house-price-data
import pandas as pd
import numpy as np
df = pd.read_csv('/content/Boston-house-price-data.csv')

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#linear regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/content/Boston-house-price-data.csv")

X = df["NOX"].values.reshape(-1, 1)
y = df["AGE"].values

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

regressor = LinearRegression()

regressor.fit(x_train, y_train)

y_pred_test = regressor.predict(x_test)
y_pred_train = regressor.predict(x_train)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_train, y_pred_train, color="red", label="Regression Line")
plt.title("Linear Regression")
plt.xlabel("NOX")
plt.ylabel("AGE")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("/content/Boston-house-price-data.csv")

X = df[["DIS"]]
y = df["ZN"]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2/4, random_state=100)

model = LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_test, y_pred, color="red", label="Regression Line")
plt.title("multiple Linear Regression")
plt.xlabel("DIS")
plt.ylabel("ZN")
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 278.6026764773452
# R-squared: 0.4491112051488433

# %%
#eda
import pandas as pd
import numpy as np
df=pd.read_csv("/content/Boston-house-price-data.csv")

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))
# Out:
# CRIM       0.0
# ZN         0.0
# INDUS      0.0
# CHAS       0.0
# NOX        0.0
# RM         0.0
# AGE        0.0
# DIS        0.0
# RAD        0.0
# TAX        0.0
# PTRATIO    0.0
# B          0.0
# LSTAT      0.0
# MEDV       0.0
# dtype: float64

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
df1=df.dropna()
print(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df2=df.dropna(axis=1)
print(df2)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df3=df.fillna(df.mean())
print(df3)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
a=len(df)
b=len(df[df['NOX'] > df['AGE']])
probability=b/a
print("probability:",probability)
# Out:
# probability: 0.0

# %%
#unique function
print(df.MEDV.unique())
print(df.B.nunique())
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  21.7 20.4 18.2
#  19.9 23.1 17.5 20.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8 18.4 21.
#  12.7 13.2 13.1 13.5 20.  24.7 30.8 34.9 26.6 25.3 21.2 19.3 14.4 19.4
#  19.7 20.5 25.  23.4 35.4 31.6 23.3 18.7 16.  22.2 33.  23.5 22.  17.4
#  20.9 24.2 22.8 24.1 21.4 20.8 20.3 28.  23.9 24.8 22.5 23.6 22.6 20.6
#  28.4 38.7 43.8 33.2 27.5 26.5 18.6 20.1 19.5 19.8 18.8 18.5 18.3 19.2
#  17.3 15.7 16.2 18.  14.3 23.  18.1 17.1 13.3 17.8 14.  13.4 11.8 13.8
#  14.6 15.4 21.5 15.3 17.  41.3 24.3 27.  50.  22.7 23.8 22.3 19.1 29.4
#  23.2 24.6 29.9 37.2 39.8 37.9 32.5 26.4 29.6 32.  29.8 37.  30.5 36.4
#  31.1 29.1 33.3 30.3 34.6 32.9 42.3 48.5 24.4 22.4 28.1 23.7 26.7 30.1
#  44.8 37.6 46.7 31.5 31.7 41.7 48.3 29.  25.1 17.6 24.5 26.2 42.8 21.9
#  44.  36.  33.8 43.1 48.8 31.  36.5 30.7 43.5 20.7 21.1 25.2 35.2 32.4
#  33.1 35.1 45.4 46.  32.2 28.5 37.3 27.9 28.6 36.1 28.2 16.1 22.1 19.
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df[['MEDV']]
y = df['B']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
print("Training set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)
# Out:
# Training set: (404, 1) (404,)
# Test set: (102, 1) (102,)

# %%
df=df.drop(["RM"],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   AGE      506 non-null    float64
#  6   DIS      506 non-null    float64
#  7   RAD      506 non-null    int64
#  8   TAX      506 non-null    float64
#  9   PTRATIO  506 non-null    float64
#  10  B        506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(11), int64(2)
# memory usage: 51.5 KB

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols=df.select_dtypes(include=np.number).columns.tolist()
print("categorical variables:")
print(cat_cols)
print("numerical variables")
print(num_cols)
# Out:
# categorical variables:
# Index([], dtype='object')
# numerical variables
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
#AB-de-Villiers-All-International-Cricket-Centuries
import pandas as pd
import numpy as np
df = pd.read_csv('/content/AB-de-Villiers-All-International-Cricket-Centuries.csv')

# %%
df.describe()
# Out:
#              No.   Position    Innings
# count  47.000000  47.000000  47.000000
# mean   24.000000   4.297872   1.617021
# std    13.711309   1.266884   0.795454
# min     1.000000   1.000000   1.000000
# 25%    12.500000   4.000000   1.000000
# 50%    24.000000   5.000000   1.000000
# 75%    35.500000   5.000000   2.000000
# max    47.000000   6.000000   4.000000

# %%
#linear regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/content/AB-de-Villiers-All-International-Cricket-Centuries.csv")

X = df["Position"].values.reshape(-1, 1)
y = df["Innings"].values

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

regressor = LinearRegression()

regressor.fit(x_train, y_train)

y_pred_test = regressor.predict(x_test)
y_pred_train = regressor.predict(x_train)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_train, y_pred_train, color="red", label="Regression Line")
plt.title("Linear Regression")
plt.xlabel("Position")
plt.ylabel("Innings")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("/content/AB-de-Villiers-All-International-Cricket-Centuries.csv")

X = df[["Innings"]]
y = df["Position"]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2/4, random_state=100)

model = LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_test, y_pred, color="red", label="Regression Line")
plt.title("multiple Linear Regression")
plt.xlabel("Innings")
plt.ylabel("Position")
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 1.752333360038455
# R-squared: -0.07951231591673813

# %%
#eda
import pandas as pd
import numpy as np
df=pd.read_csv("/content/AB-de-Villiers-All-International-Cricket-Centuries.csv")

# %%
df.describe()
# Out:
#              No.   Position    Innings
# count  47.000000  47.000000  47.000000
# mean   24.000000   4.297872   1.617021
# std    13.711309   1.266884   0.795454
# min     1.000000   1.000000   1.000000
# 25%    12.500000   4.000000   1.000000
# 50%    24.000000   5.000000   1.000000
# 75%    35.500000   5.000000   2.000000
# max    47.000000   6.000000   4.000000

# %%
df.head()
# Out:
#    No. Score       Against  Position  Innings  \
# 0    1   109       England         1        3
# 1    2   178   West Indies         2        2
# 2    3   114   West Indies         1        1
# 3    4   146   West Indies         1        1
# 4    5   107      Zimbabwe         4        1
#
#                                    Venue Ground       Date Result
# 0             SuperSport Park, Centurion   Home  21-Jan-05  Drawn
# 1            Kensington Oval, Bridgetown   Away  21-Apr-05    Won
# 2   Antigua Recreation Ground, St John's   Away  29-Apr-05  Drawn
# 3  National Cricket Stadium, St George's   Away  10-Apr-07    Won
# 4             Harare Sports Club, Harare   Away  26-Aug-07    Won

# %%
df.tail()
# Out:
#     No. Score      Against  Position  Innings  \
# 42   43   112        India         4        2
# 43   44   119        India         4        1
# 44   45  101*      England         5        2
# 45   46   176   Bangladesh         4        1
# 46   47  126*    Australia         5        2
#
#                                  Venue Ground       Date Result
# 42  M. A. Chidambaram Stadium, Chennai   Away  22-Oct-15   Lost
# 43            Wankhede Stadium, Mumbai   Away  25-Oct-15    Won
# 44  Newlands Cricket Ground, Cape Town   Home  14-Feb-16    Won
# 45                  Boland Park, Paarl   Home  18-Oct-17    Won
# 46    St George's Park, Port Elizabeth   Home  09-Mar-18    Won

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       47 non-null     int64
#  1   Score     47 non-null     object
#  2   Against   47 non-null     object
#  3   Position  47 non-null     int64
#  4   Innings   47 non-null     int64
#  5   Venue     47 non-null     object
#  6   Ground    47 non-null     object
#  7   Date      47 non-null     object
#  8   Result    47 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 3.4+ KB

# %%
df.nunique()
# Out:
# No.         47
# Score       41
# Against     10
# Position     6
# Innings      4
# Venue       31
# Ground       3
# Date        47
# Result       5
# dtype: int64

# %%
df.isnull().sum()
# Out:
# No.         0
# Score       0
# Against     0
# Position    0
# Innings     0
# Venue       0
# Ground      0
# Date        0
# Result      0
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))
# Out:
# No.         0.0
# Score       0.0
# Against     0.0
# Position    0.0
# Innings     0.0
# Venue       0.0
# Ground      0.0
# Date        0.0
# dtype: float64

# %%
df.describe().T
# Out:
#           count       mean        std  min   25%   50%   75%   max
# No.        47.0  24.000000  13.711309  1.0  12.5  24.0  35.5  47.0
# Position   47.0   4.297872   1.266884  1.0   4.0   5.0   5.0   6.0
# Innings    47.0   1.617021   0.795454  1.0   1.0   1.0   2.0   4.0

# %%
df1=df.dropna()
print(df)
# Out:
#     No.  Score       Against  Position  Innings  \
# 0     1    109       England         1        3
# 1     2    178   West Indies         2        2
# 2     3    114   West Indies         1        1
# 3     4    146   West Indies         1        1
# 4     5    107      Zimbabwe         4        1
# 5     6  103*       Pakistan         4        1
# 6     7   103*   West Indies         6        2
# 7     8  217*          India         6        2
# 8     9    174       England         6        2
# 9    10  106*      Australia         5        4
# 10   11   104*     Australia         5        2
# 11   12    163     Australia         5        2
# 12   13    121       England         3        1
# 13   14   114*         India         5        2
# 14   15  102*          India         4        1
# 15   16    102   West Indies         4        1
# 16   17   135*   West Indies         5        1
# 17   18   101*      Zimbabwe         3        2
# ...

# %%
df2=df.dropna(axis=1)
print(df2)
# Out:
#     No.  Score       Against  Position  Innings  \
# 0     1    109       England         1        3
# 1     2    178   West Indies         2        2
# 2     3    114   West Indies         1        1
# 3     4    146   West Indies         1        1
# 4     5    107      Zimbabwe         4        1
# 5     6  103*       Pakistan         4        1
# 6     7   103*   West Indies         6        2
# 7     8  217*          India         6        2
# 8     9    174       England         6        2
# 9    10  106*      Australia         5        4
# 10   11   104*     Australia         5        2
# 11   12    163     Australia         5        2
# 12   13    121       England         3        1
# 13   14   114*         India         5        2
# 14   15  102*          India         4        1
# 15   16    102   West Indies         4        1
# 16   17   135*   West Indies         5        1
# 17   18   101*      Zimbabwe         3        2
# ...

# %%
df3=df.fillna(df.mean())
print(df3)
# Out:
#     No.  Score       Against  Position  Innings  \
# 0     1    109       England         1        3
# 1     2    178   West Indies         2        2
# 2     3    114   West Indies         1        1
# 3     4    146   West Indies         1        1
# 4     5    107      Zimbabwe         4        1
# 5     6  103*       Pakistan         4        1
# 6     7   103*   West Indies         6        2
# 7     8  217*          India         6        2
# 8     9    174       England         6        2
# 9    10  106*      Australia         5        4
# 10   11   104*     Australia         5        2
# 11   12    163     Australia         5        2
# 12   13    121       England         3        1
# 13   14   114*         India         5        2
# 14   15  102*          India         4        1
# 15   16    102   West Indies         4        1
# 16   17   135*   West Indies         5        1
# 17   18   101*      Zimbabwe         3        2
# ...

# %%
a=len(df)
b=len(df[df['Position'] > df['Innings']])
probability=a/b
print("probability:",probability)
# Out:
# probability: 1.0930232558139534

# %%
#unique function
print(df.Score.unique())
print(df.Ground.nunique())
# Out:
# ['109' '178' '114' '146' '107' '103* ' '103*' '217* ' '174' '106* ' '104*'
#  '163' '121' '114*' '102* ' '102' '135*' '101*' '278* ' '129' '107* '
#  '134' '160*' '125*' '106*' '169' '128' '164' '115*' '103' '116' '108'
#  '136*' '152' '148' '149' '162*' '112' '119' '176' '126*']
# 3

# %%
df=df.drop(["Result"],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       47 non-null     int64
#  1   Score     47 non-null     object
#  2   Against   47 non-null     object
#  3   Position  47 non-null     int64
#  4   Innings   47 non-null     int64
#  5   Venue     47 non-null     object
#  6   Ground    47 non-null     object
#  7   Date      47 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 3.1+ KB

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols=df.select_dtypes(include=np.number).columns.tolist()
print("categorical variables:")
print(cat_cols)
print("numerical variables")
print(num_cols)
# Out:
# categorical variables:
# Index(['Score', 'Against', 'Venue', 'Ground', 'Date'], dtype='object')
# numerical variables
# ['No.', 'Position', 'Innings']

# %%
#Cricket match result - past data
import pandas as pd
import numpy as np
df = pd.read_csv('/content/matches.csv')

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
#linear regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/content/matches.csv")

X = df["season"].values.reshape(-1, 1)
y = df["dl_applied"].values

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

regressor = LinearRegression()

regressor.fit(x_train, y_train)

y_pred_test = regressor.predict(x_test)
y_pred_train = regressor.predict(x_train)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_train, y_pred_train, color="red", label="Regression Line")
plt.title("Linear Regression")
plt.xlabel("season")
plt.ylabel("dl_applied")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("/content/matches.csv")

X = df[["win_by_runs"]]
y = df["win_by_wickets"]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2/4, random_state=100)

model = LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_test, y_pred, color="red", label="Regression Line")
plt.title("multiple Linear Regression")
plt.xlabel("win_by_runs")
plt.ylabel("win_by_wickets")
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 8.16953626659814
# R-squared: 0.28433215597646977

# %%
#eda
import pandas as pd
import numpy as np
df=pd.read_csv("/content/matches.csv")

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.nunique()
# Out:
# id                 636
# season              10
# city                30
# date               450
# team1               14
# team2               14
# toss_winner         14
# toss_decision        2
# result               3
# dl_applied           2
# winner              14
# win_by_runs         86
# win_by_wickets      11
# player_of_match    201
# venue               35
# umpire1             44
# umpire2             45
# umpire3              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))
# Out:
# id                 0.000000
# season             0.000000
# city               0.011006
# date               0.000000
# team1              0.000000
# team2              0.000000
# toss_winner        0.000000
# toss_decision      0.000000
# result             0.000000
# dl_applied         0.000000
# winner             0.004717
# win_by_runs        0.000000
# win_by_wickets     0.000000
# player_of_match    0.004717
# venue              0.000000
# umpire1            0.001572
# umpire2            0.001572
# umpire3            1.000000
# dtype: float64

# %%
df.describe().T
# Out:
#                 count         mean         std     min      25%     50%  \
# id              636.0   318.500000  183.741666     1.0   159.75   318.5
# season          636.0  2012.490566    2.773026  2008.0  2010.00  2012.0
# dl_applied      636.0     0.025157    0.156726     0.0     0.00     0.0
# win_by_runs     636.0    13.682390   23.908877     0.0     0.00     0.0
# win_by_wickets  636.0     3.372642    3.420338     0.0     0.00     4.0
# umpire3           0.0          NaN         NaN     NaN      NaN     NaN
#
#                     75%     max
# id               477.25   636.0
# season          2015.00  2017.0
# dl_applied         0.00     1.0
# win_by_runs       20.00   146.0
# win_by_wickets     7.00    10.0
# umpire3             NaN     NaN

# %%
df1=df.dropna()
print(df)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df2=df.dropna(axis=1)
print(df2)
# Out:
#       id  season        date                        team1  \
# 0      1    2017  2017-04-05          Sunrisers Hyderabad
# 1      2    2017  2017-04-06               Mumbai Indians
# 2      3    2017  2017-04-07                Gujarat Lions
# 3      4    2017  2017-04-08       Rising Pune Supergiant
# 4      5    2017  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...         ...                          ...
# 631  632    2016  2016-05-22             Delhi Daredevils
# 632  633    2016  2016-05-24                Gujarat Lions
# 633  634    2016  2016-05-25          Sunrisers Hyderabad
# 634  635    2016  2016-05-27                Gujarat Lions
# 635  636    2016  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
df3=df.fillna(df.mean())
print(df3)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
a=len(df)
b=len(df[df['win_by_runs'] > df['win_by_wickets']])
probability=a/b
print("probability:",probability)
# Out:
# probability: 2.21602787456446

# %%
#unique function
print(df.win_by_runs.unique())
print(df.win_by_wickets.nunique())
# Out:
# [ 35   0  15  97  17  51  27   5  21  14  26  82   3  61  48  19  12 146
#    7   9  10  20   1 140  33   6  66  13  45  29  18  23  41  65  25 105
#   75  92  11  24  38   8  78  16  53   2   4  31  55  98  34  36  39  40
#   67  63  37  57  22  85  32  76 111  43  58  28  74  42  59  46  47  86
#   44  87 130  60  77  30  50  93  72  62 138  71 144  80]
# 11

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols=df.select_dtypes(include=np.number).columns.tolist()
print("categorical variables:")
print(cat_cols)
print("numerical variables")
print(num_cols)
# Out:
# categorical variables:
# Index(['city', 'date', 'team1', 'team2', 'toss_winner', 'toss_decision',
#        'result', 'winner', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')
# numerical variables
# ['id', 'season', 'dl_applied', 'win_by_runs', 'win_by_wickets', 'umpire3']

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/crop yield.csv')

# %%
df.describe()
# Out:
#          Unnamed: 0          Year    hg/ha_yield  \
# count  28242.000000  28242.000000   28242.000000
# mean   14120.500000   2001.544296   77053.332094
# std     8152.907488      7.051905   84956.612897
# min        0.000000   1990.000000      50.000000
# 25%     7060.250000   1995.000000   19919.250000
# 50%    14120.500000   2001.000000   38295.000000
# 75%    21180.750000   2008.000000  104676.750000
# max    28241.000000   2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes      avg_temp
# count                    28242.00000       28242.000000  28242.000000
# mean                      1149.05598       37076.909344     20.542627
# std                        709.81215       59958.784665      6.312051
# min                         51.00000           0.040000      1.300000
# 25%                        593.00000        1702.000000     16.702500
# 50%                       1083.00000       17529.440000     21.510000
# ...

# %%
#linear regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/content/crop yield.csv")

X = df["hg/ha_yield"].values.reshape(-1, 1)
y = df["average_rain_fall_mm_per_year"].values

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

regressor = LinearRegression()

regressor.fit(x_train, y_train)

y_pred_test = regressor.predict(x_test)
y_pred_train = regressor.predict(x_train)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_train, y_pred_train, color="red", label="Regression Line")
plt.title("Linear Regression")
plt.xlabel("hg/ha_yield")
plt.ylabel("average_rain_fall_mm_per_year")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("/content/crop yield.csv")

X = df[["pesticides_tonnes"]]
y = df["avg_temp"]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2/4, random_state=100)

model = LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)

plt.scatter(x_test, y_test, color="green", label="Testing Data")
plt.plot(x_test, y_pred, color="red", label="Regression Line")
plt.title("multiple Linear Regression")
plt.xlabel("pesticides_tonnes")
plt.ylabel("avg_temp")
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 39.98262245010746
# R-squared: 0.0008994108576300119

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/crop yield.csv")

# %%
df.describe()
# Out:
#          Unnamed: 0          Year    hg/ha_yield  \
# count  28242.000000  28242.000000   28242.000000
# mean   14120.500000   2001.544296   77053.332094
# std     8152.907488      7.051905   84956.612897
# min        0.000000   1990.000000      50.000000
# 25%     7060.250000   1995.000000   19919.250000
# 50%    14120.500000   2001.000000   38295.000000
# 75%    21180.750000   2008.000000  104676.750000
# max    28241.000000   2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes      avg_temp
# count                    28242.00000       28242.000000  28242.000000
# mean                      1149.05598       37076.909344     20.542627
# std                        709.81215       59958.784665      6.312051
# min                         51.00000           0.040000      1.300000
# 25%                        593.00000        1702.000000     16.702500
# 50%                       1083.00000       17529.440000     21.510000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
df.tail()
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 28237                          657.0            2550.07     19.76
# 28238                          657.0            2550.07     19.76
# 28239                          657.0            2550.07     19.76
# 28240                          657.0            2550.07     19.76
# 28241                          657.0            2550.07     19.76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     28242 non-null  int64
#  1   Area                           28242 non-null  object
#  2   Item                           28242 non-null  object
#  3   Year                           28242 non-null  int64
#  4   hg/ha_yield                    28242 non-null  int64
#  5   average_rain_fall_mm_per_year  28242 non-null  float64
#  6   pesticides_tonnes              28242 non-null  float64
#  7   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.7+ MB

# %%
df.nunique()
# Out:
# Unnamed: 0                       28242
# Area                               101
# Item                                10
# Year                                23
# hg/ha_yield                      11514
# average_rain_fall_mm_per_year      100
# pesticides_tonnes                 1673
# avg_temp                          1831
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))
# Out:
# Unnamed: 0                       0.0
# Area                             0.0
# Item                             0.0
# Year                             0.0
# hg/ha_yield                      0.0
# average_rain_fall_mm_per_year    0.0
# pesticides_tonnes                0.0
# avg_temp                         0.0
# dtype: float64

# %%
df.describe().T
# Out:
#                                  count          mean           std      min  \
# Unnamed: 0                     28242.0  14120.500000   8152.907488     0.00
# Year                           28242.0   2001.544296      7.051905  1990.00
# hg/ha_yield                    28242.0  77053.332094  84956.612897    50.00
# average_rain_fall_mm_per_year  28242.0   1149.055980    709.812150    51.00
# pesticides_tonnes              28242.0  37076.909344  59958.784665     0.04
# avg_temp                       28242.0     20.542627      6.312051     1.30
#
#                                       25%       50%        75%        max
# Unnamed: 0                      7060.2500  14120.50   21180.75   28241.00
# Year                            1995.0000   2001.00    2008.00    2013.00
# hg/ha_yield                    19919.2500  38295.00  104676.75  501412.00
# average_rain_fall_mm_per_year    593.0000   1083.00    1668.00    3240.00
# ...

# %%
df1=df.dropna()
print(df)
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
df2=df.dropna(axis=1)
print(df2)
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
df3=df.fillna(df.mean())
print(df3)
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
a=len(df)
b=len(df[df['Area'] > df['Item']])
probability=a/b
print("probability:",probability)
# Out:
# probability: 5.134909090909091

# %%
#unique function
print(df.Area.unique())
print(df.Item.nunique())
# Out:
# ['Albania' 'Algeria' 'Angola' 'Argentina' 'Armenia' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh' 'Belarus' 'Belgium'
#  'Botswana' 'Brazil' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cameroon'
#  'Canada' 'Central African Republic' 'Chile' 'Colombia' 'Croatia'
#  'Denmark' 'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'Eritrea'
#  'Estonia' 'Finland' 'France' 'Germany' 'Ghana' 'Greece' 'Guatemala'
#  'Guinea' 'Guyana' 'Haiti' 'Honduras' 'Hungary' 'India' 'Indonesia' 'Iraq'
#  'Ireland' 'Italy' 'Jamaica' 'Japan' 'Kazakhstan' 'Kenya' 'Latvia'
#  'Lebanon' 'Lesotho' 'Libya' 'Lithuania' 'Madagascar' 'Malawi' 'Malaysia'
#  'Mali' 'Mauritania' 'Mauritius' 'Mexico' 'Montenegro' 'Morocco'
#  'Mozambique' 'Namibia' 'Nepal' 'Netherlands' 'New Zealand' 'Nicaragua'
#  'Niger' 'Norway' 'Pakistan' 'Papua New Guinea' 'Peru' 'Poland' 'Portugal'
#  'Qatar' 'Romania' 'Rwanda' 'Saudi Arabia' 'Senegal' 'Slovenia'
# ...

# %%
df=df.drop(["Unnamed: 0"],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols=df.select_dtypes(include=np.number).columns.tolist()
print("categorical variables:")
print(cat_cols)
print("numerical variables")
print(num_cols)
# Out:
# categorical variables:
# Index(['Area', 'Item'], dtype='object')
# numerical variables
# ['Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp']
